span class="sc-1s278lr-0 dkVEdQ" data-testid=""><svg class="av-icon sc-1s278lr-1 lpsHjP" height="12" width="12" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg" aria-labelledby="Store2FillTitleID" style="fill: currentcolor; stroke: currentcolor; stroke-width: 0;"><title id="Store2FillTitleID">Store2Fill Icon</title><path d="M22 20v2H2v-2h1v-6.758A4.496 4.496 0 011 9.5c0-.827.224-1.624.633-2.303L4.345 2.5a1 1 0 01.866-.5H18.79a1 1 0 01.866.5l2.702 4.682A4.496 4.496 0 0121 13.242V20h1zM5.789 4L3.356 8.213a2.5 2.5 0 004.466 2.216c.335-.837 1.52-.837 1.856 0a2.5 2.5 0 004.644 0c.335-.837 1.52-.837 1.856 0a2.5 2.5 0 104.457-2.232L18.21 4H5.79z"></path></svg><span style="line-height:1">Boutique</span></span></div></div></div><div class="sc-b57yxx-1 kBlnTB"><div><div class="sc-b57yxx-7 nCYxr"><div class="sc-b57yxx-8 cnMHvz"><svg class="av-icon sc-b57yxx-6 cKPbFc" height="19" width="19" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg" aria-labelledby="LocationTitleID" style="fill: currentcolor; stroke: currentcolor; stroke-width: 0;"><title id="LocationTitleID">Location Icon</title><path d="M14.004 21.99a.87.87 0 00.142.01c.45 0 .865-.29 1.032-.739l6.688-17.648a1.218 1.218 0 00-.245-1.268 1.072 1.072 0 00-1.201-.261L3.7 9.144c-.47.199-.756.71-.69 1.239.064.534.463.953.966 1.019l8.057 1.063 1.008 8.504c.062.532.459.953.963 1.021z"></path></svg><p class="sc-1x0vz2r-0 iFQpLP" style="line-height:1">Voitures d'occasion dans Rabat, Yacoub El Mansour</p></div></div><p class="sc-1x0vz2r-0 czqClV" style="line-height:1.4;margin-top:4" title="Peugeot 508 Diesel Manuelle 2013 à Rabat">Peugeot 508 Diesel Manuelle 2013 à Rabat</p><div class="sc-b57yxx-2 jhthcs"><span class="sc-1s278lr-0 cAiIZZ" data-testid=""><span style="line-height:1"><div style="display:flex;align-items:center;gap:6px" title="Puissance fiscale"><div style="width:12px;height:12px;background-color:currentColor;-webkit-mask:url(&quot;https://assets.avito.ma/icons/svg/adparam_pfiscale.svg&quot;) no-repeat center;mask:url(&quot;https://assets.avito.ma/icons/svg/adparam_pfiscale.svg&quot;) no-repeat center;-webkit-mask-size:contain;mask-size:contain"></div><span>8 CV<!-- --> </span></div></span></span><span class="sc-1s278lr-0 cAiIZZ" data-testid=""><span style="line-height:1"><div style="display:flex;align-items:center;gap:6px" title="Boite de vitesses"><div style="width:12px;height:12px;background-color:currentColor;-webkit-mask:url(&quot;https://assets.avito.ma/icons/svg/adparam_bv.svg&quot;) no-repeat center;mask:url(&quot;https://assets.avito.ma/icons/svg/adparam_bv.svg&quot;) no-repeat center;-webkit-mask-size:contain;mask-size:contain"></div><span>Manuelle<!-- --> </span></div></span></span><span class="sc-1s278lr-0 cAiIZZ" data-testid=""><span style="line-height:1"><div style="display:flex;align-items:center;gap:6px" title="Type de carburant"><div style="width:12px;height:12px;background-color:currentColor;-webkit-mask:url(&quot;https://assets.avito.ma/icons/svg/adparam_fuel.svg&quot;) no-repeat center;mask:url(&quot;https://assets.avito.ma/icons/svg/adparam_fuel.svg&quot;) no-repeat center;-webkit-mask-size:contain;mask-size:contain"></div><span>Diesel<!-- --> </span></div></span></span></div></div><div class="sc-b57yxx-0 ckugTG"><div class="sc-b57yxx-4 dRjnHr"><p class="sc-1x0vz2r-0 eCXWei sc-b57yxx-3 IneBF">Prix non spécifié</p></div><button class="sc-w5ky4o-0 bboFSP" data-testid="" type="button"><svg class="av-icon" height="24" width="24" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg" aria-labelledby="HeartTitleID" style="fill: rgb(155, 155, 155); stroke: rgb(155, 155, 155); stroke-width: 0;"><title id="HeartTitleID">Heart Icon</title><path d="M6.483 3.315c-3.671 1.182-5.31 5.19-4.078 9.014a12.408 12.408 0 002.975 4.747 34.717 34.717 0 006.005 4.673l.245.147c.236.14.53.138.763-.006l.229-.143a34.695 34.695 0 005.995-4.665 12.42 12.42 0 002.977-4.737c1.235-3.837-.41-7.847-4.082-9.03l-.266-.079a6.571 6.571 0 00-4.981.62l-.269.158-.263-.158a6.562 6.562 0 00-5.25-.54z"></path></svg></button></div></div></a></div>
"""

# %%
url="https://www.avito.ma/fr/maroc/voitures"

# Définir un en-tête d'agent utilisateur pour simuler un navigateur
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)

html=response.content

# %%
# URL de base
base_url = "https://www.avito.ma/fr/maroc/voitures"

# Définir un en-tête d'agent utilisateur pour simuler un navigateur
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# %%
# Fonction pour récupérer le nombre total de pages de pagination disponibles
def get_total_pages(url):
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        # Trouver le lien de la dernière page et extraire le numéro de page
        last_page_link = soup.find("a", class_="pagination-last")
        if last_page_link:
            last_page_url = last_page_link.get("href")
            total_pages = int(last_page_url.split("=")[-1])
            return total_pages
    return 0

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(soup.prettify())
#
# NameError: name 'soup' is not defined

# %%
car_links = soup.find_all("a", class_="sc-1jge648-0")
car_links
# Out:
# [<a class="sc-1jge648-0 eTbzNs" href="https://www.avito.ma/fr/azli/voitures_d'occasion/Toyota_Land_Cruiser_200_V8_Automatique_54196231.htm"><div class="sc-1wnmz4-0 gjIrxt"><div class="sc-1wnmz4-1 cEeszA"><div class="sc-1wnmz4-4 iaGDJA"><img class="sc-1wnmz4-6 ldofUR" src="/phoenix-assets/imgs/profile/avatar.svg"/></div><div><div class="sc-1wnmz4-1 sc-1wnmz4-2 cEeszA cjNTAP"><p class="sc-1x0vz2r-0 dNKvDA" font-weight="600">Mohamed</p></div><div class="sc-1wnmz4-3 hvJyEm"><div style="width:12px;height:12px;background-color:rgba(242, 242, 242,0.2);border-radius:50px"></div><p class="sc-1x0vz2r-0 iFQpLP">il y a 7 minutes</p></div></div></div></div><div class="sc-bsm2tm-0 kvxLpd"><div class="sc-bsm2tm-1 sUHsx"><div class="sc-bsm2tm-5 kXNFky"></div><div class="sc-bsm2tm-2 hLaJMz"><img class="sc-bsm2tm-3 dQOodK" loading="lazy" src="https://content.avito.ma/classifieds/images/10115854943?t=images"/></div><div class="sc-bsm2tm-5 bymZlq"><span class="sc-1s278lr-0 dkVEdQ" data-testid=""><div cl
# ...

# %%
# Liste des informations à extraire
car_info = []

# %%
# Analyser chaque lien avec BeautifulSoup
for link in car_links:
      # Obtenir le lien URL
    url = link.get('href')
    # Obtenir le nom du vendeur
    seller_name = link.find('p', class_='sc-1x0vz2r-0 dNKvDA').text.strip()
    # Extraire le titre de la voiture
    car_title = link.find('p', class_='sc-1x0vz2r-0 czqClV').text.strip()
    # Obtenir le type de carburant
    #fuel_type = link.find('div', {'title': 'Type de carburant'}).find('span').get_text(strip=True)
    
    # Obtenir le type de carburant
    fuel_type_tag = link.find('div', {'title': 'Type de carburant'})
    if fuel_type_tag:
        fuel_type = fuel_type_tag.find('span').get_text(strip=True)
    else:
        fuel_type = "Non spécifié"

    # Obtenir la boîte de vitesses
    #transmission = link.find('div', {'title': 'Boite de vitesses'}).find('span').text.strip()
    
    # Obtenir la boîte de vitesses
    transmission_tag = link.find('div', {'title': 'Boite de vitesses'})
    if transmission_tag:
        transmission = transmission_tag.find('span').text.strip()
    else:
        transmission = "Non spécifié"
        
    # Obtenir la puissance fiscale
    #fiscal_power = link.find('div', {'title': 'Puissance fiscale'}).find('span').get_text(strip=True)
    
    # Obtenir la puissance fiscale
    fiscal_power_tag = link.find('div', {'title': 'Puissance fiscale'})
    if fiscal_power_tag:
        fiscal_power = fiscal_power_tag.find('span').get_text(strip=True)
    else:
        fiscal_power = "Non spécifié"
    
    
    # Rechercher la balise <p> sous la balise <div> avec la classe spécifiée
    prix_balise = link.find('div', {'class': 'sc-b57yxx-4 dRjnHr'}).find('p')
    
    # Vérifier si la balise <p> contient un prix spécifié
    if prix_balise.span:
        # Extraire le prix spécifié
        car_price = prix_balise.span.get_text(strip=True)
    else:
        # Extraire le texte lorsque le prix n'est pas spécifié
        car_price = prix_balise.get_text(strip=True)

    
    # Ajouter les informations extraites à la liste
    car_info.append({
        'URL': url,
        'Nom du vendeur': seller_name,
        'Titre de la voiture': car_title,
        'Type de carburant': fuel_type,
        'Boîte de vitesses': transmission,
        'Puissance fiscale': fiscal_power,
        'Prix':car_price
    })

# %%
# Convertir la liste en DataFrame pandas
df = pd.DataFrame(car_info)
df
# Out:
#                                                   URL        Nom du vendeur  \
# 0   https://www.avito.ma/fr/azli/voitures_d'occasi...               Mohamed
# 1   https://www.avito.ma/fr/ain_sebaa/voitures_d'o...          Global occaz
# 2   https://www.avito.ma/fr/centre_ville/location_...  Platino Car Services
# 3   https://www.avito.ma/fr/al_hoceima/voitures_d'...      al akhawayn Auto
# 4   https://www.avito.ma/fr/ain_sebaa/voitures_d'o...       TOYOTA OCCASION
# 5   https://www.avito.ma/fr/anfa/voitures_d'occasi...         Corniche auto
# 6   https://www.avito.ma/fr/salé/location_de_voitu...              PATH CAR
# 7   https://www.avito.ma/fr/aïn_chock/location_de_...                2AMCAR
# 8   https://www.avito.ma/fr/route_de_sefrou/voitur...          NEW AUTO GHT
# 9   https://www.avito.ma/fr/anoual_souss/voitures_...                Agadir
# 10  https://www.avito.ma/fr/narjis/voitures_d'occa...           particulier
# ...

# %%
# Spécifiez le chemin du fichier CSV de sortie
output_csv_file = "car_info.csv"

# Enregistrez le DataFrame dans un fichier CSV
df.to_csv(output_csv_file, index=False)

print("Le DataFrame a été enregistré dans le fichier CSV :", output_csv_file)
# Out:
# Le DataFrame a été enregistré dans le fichier CSV : car_info.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de base
base_url = "https://www.avito.ma/fr/maroc/voitures"
# Nombre total de pages 2701
total_pages = 1000

# Définir un en-tête d'agent utilisateur pour simuler un navigateur
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# Fonction pour récupérer les données d'une page donnée
def scrape_page(url):
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        # Scraper les données dont vous avez besoin ici
        car_links = soup.find_all("a", class_="sc-1jge648-0") # Liste des informations à extraire
        car_info = [] # Analyser chaque lien avec BeautifulSoup
        for link in car_links:
            # Obtenir le lien URL
            url = link.get('href')
            # Obtenir le nom du vendeur
            seller_name = link.find('p', class_='sc-1x0vz2r-0 dNKvDA').text.strip()
            # Extraire le titre de la voiture
            car_title = link.find('p', class_='sc-1x0vz2r-0 czqClV').text.strip()
            # Obtenir le type de carburant
            fuel_type_tag = link.find('div', {'title': 'Type de carburant'})
            fuel_type = fuel_type_tag.find('span').get_text(strip=True) if fuel_type_tag else "Non spécifié"
            # Obtenir la boîte de vitesses
            transmission_tag = link.find('div', {'title': 'Boite de vitesses'})
            transmission = transmission_tag.find('span').text.strip() if transmission_tag else "Non spécifié"
            # Obtenir la puissance fiscale
            fiscal_power_tag = link.find('div', {'title': 'Puissance fiscale'})
            fiscal_power = fiscal_power_tag.find('span').get_text(strip=True) if fiscal_power_tag else "Non spécifié"
            # Obtenir le prix
            prix_balise = link.find('div', {'class': 'sc-b57yxx-4 dRjnHr'}).find('p')
            car_price = prix_balise.span.get_text(strip=True) if prix_balise.span else prix_balise.get_text(strip=True)
            # Ajouter les informations extraites à la liste
            car_info.append({
                'URL': url,
                'Nom du vendeur': seller_name,
                'Titre de la voiture': car_title,
                'Type de carburant': fuel_type,
                'Boîte de vitesses': transmission,
                'Puissance fiscale': fiscal_power,
                'Prix': car_price
            })
        return car_info
    else:
        print("Erreur lors de la requête :", response.status_code)
        return []

# Liste pour stocker toutes les données
all_car_info = []

# Parcourir chaque page et récupérer les données
for page_number in range(1, total_pages + 1):
    page_url = f"{base_url}?o={page_number}"
    print(f"Scraping page {page_number}...")
    page_data = scrape_page(page_url)
    if page_data:
        all_car_info.extend(page_data)  # Ajouter les données de cette page à la liste

# Convertir la liste de données en DataFrame
df = pd.DataFrame(all_car_info)

# Enregistrer le DataFrame dans un fichier CSV
df.to_csv('voitures_avito.csv', index=False)
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# Scraping page 16...
# Scraping page 17...
# Scraping page 18...
# Scraping page 19...
# Scraping page 20...
# Scraping page 21...
# Scraping page 22...
# Scraping page 23...
# Scraping page 24...
# Scraping page 25...
# Scraping page 26...
# Scraping page 27...
# Scraping page 28...
# Scraping page 29...
# Scraping page 30...
# Scraping page 31...
# Scraping page 32...
# Scraping page 33...
# Scraping page 34...
# Scraping page 35...
# Scraping page 36...
# Scraping page 37...
# Scraping page 38...
# Scraping page 39...
# Scraping page 40...
# Scraping page 41...
# Scraping page 42...
# Scraping page 43...
# Scraping page 44...
# Scraping page 45...
# ...

# %%
df.to_csv('voitures_avito_scarabing.csv', index=False)

# %%
df = pd.DataFrame(all_car_info)
df
# Out:
#                                                      URL  Nom du vendeur  \
# 0      https://www.avito.ma/fr/californie/voitures_d'...     hassan auto
# 1      https://www.avito.ma/fr/centre_ville/location_...   Luxuryrentcar
# 2      https://www.avito.ma/fr/centre_ville/location_...   Luxuryrentcar
# 3      https://www.avito.ma/fr/centre_ville/location_...   Luxuryrentcar
# 4      https://www.avito.ma/fr/ain_mezouar/voitures_d...  Menara 26 Auto
# ...                                                  ...             ...
# 34995  https://www.avito.ma/fr/khemisset/voitures_d'o...      سلام عليكم
# 34996  https://www.avito.ma/fr/sidi_yahya/voitures_d'...         azzaoui
# 34997  https://www.avito.ma/fr/agdal/voitures_d'occas...          Rachid
# 34998  https://www.avito.ma/fr/hay_hassani/voitures_d...         yassine
# 34999  https://www.avito.ma/fr/ben_m'sick/voitures_d'...   Amine Saadane
#
#                                      Titre de la voiture Type de carburant  \
# ...
